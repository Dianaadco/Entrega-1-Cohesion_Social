# %% [markdown]
# ---
#
# | | |
# |---|---|
# | **Curso:** | Economía Política de la Cohesión Social |
# | **Profesor:** | Emilio Depetris-Chauvin |
# | **Investigación:** | ¿Ser Sede Importa? Efectos Causales del AFCON sobre el Desarrollo Económico y la Cohesión Social |
# | **Entregable 1:** | Construcción del Dataset de Ciudades Sede |
# | **Integrantes:** | xxxxxxxxxx |
# | | xxxxxxxxxx |
# | **Fecha de Entrega:** | 22 de Abril 2025 |
#
# ---

# %% [markdown]
# ## 1. CONSTRUCCIÓN DEL DATASET DE CIUDADES SEDE

# %% [markdown]
# ### 1.1. IDENTIFICACIÓN Y VERIFICACIÓN DE CIUDADES SEDE

# %% [markdown]
# #### 1.1.1. Verificando cada observación contra fuentes primarias

# %%
import pandas as pd
import numpy as np

# %%
# Dataset .do del archivo del profesor
data = [
    # era historica (pre-satelital)
    ("1957","1957","Sudan","Khartoum",15.5007,32.5599,"1957-02-10","1957-02-16",0),
    ("1959","1959","Egypt","Cairo",30.0444,31.2357,"1959-05-22","1959-05-29",0),
    ("1959","1959","Egypt","Alexandria",31.2001,29.9187,"1959-05-22","1959-05-29",0),
    ("1962","1962","Ethiopia","Addis Ababa",9.0054,38.7636,"1962-01-10","1962-01-21",0),
    ("1963","1963","Ghana","Accra",5.6037,-0.1870,"1963-11-03","1963-11-10",0),
    ("1965","1965","Tunisia","Tunis",36.8065,10.1815,"1965-01-09","1965-01-21",0),
    ("1968","1968","Ethiopia","Addis Ababa",9.0054,38.7636,"1968-01-12","1968-01-28",0),
    ("1968","1968","Ethiopia","Asmara",15.3229,38.9251,"1968-01-12","1968-01-28",0),
    ("1970","1970","Sudan","Khartoum",15.5007,32.5599,"1970-02-03","1970-02-14",0),
    ("1972","1972","Cameroon","Yaounde",3.8480,11.5021,"1972-02-23","1972-03-05",0),
    ("1972","1972","Cameroon","Douala",4.0483,9.7043,"1972-02-23","1972-03-05",0),
    ("1974","1974","Egypt","Cairo",30.0444,31.2357,"1974-03-01","1974-03-14",0),
    ("1974","1974","Egypt","Alexandria",31.2001,29.9187,"1974-03-01","1974-03-14",0),
    ("1976","1976","Ethiopia","Addis Ababa",9.0054,38.7636,"1976-02-28","1976-03-14",0), # CORREGIDO: 29feb no existe en 1976
    ("1978","1978","Ghana","Accra",5.6037,-0.1870,"1978-03-05","1978-03-18",0),
    ("1978","1978","Ghana","Kumasi",6.6884,-1.6244,"1978-03-05","1978-03-18",0),
    ("1980","1980","Nigeria","Lagos",6.5244,3.3792,"1980-03-08","1980-03-22",0),
    ("1980","1980","Nigeria","Ibadan",7.3775,3.9470,"1980-03-08","1980-03-22",0),
    ("1980","1980","Nigeria","Benin City",6.3350,5.6270,"1980-03-08","1980-03-22",0),
    ("1982","1982","Libya","Tripoli",32.8872,13.1913,"1982-03-04","1982-03-19",0),
    ("1982","1982","Libya","Benghazi",32.1166,20.0686,"1982-03-04","1982-03-19",0),
    ("1984","1984","Ivory Coast","Abidjan",5.3599,-4.0082,"1984-03-12","1984-03-28",0),
    ("1986","1986","Egypt","Cairo",30.0444,31.2357,"1986-03-07","1986-03-21",0),
    ("1986","1986","Egypt","Alexandria",31.2001,29.9187,"1986-03-07","1986-03-21",0),
    ("1986","1986","Egypt","Port Said",31.2653,32.3019,"1986-03-07","1986-03-21",0),
    ("1988","1988","Morocco","Casablanca",33.5731,-7.5898,"1988-02-26","1988-03-12",0),
    ("2023","2024","Ivory Coast","Abidjan",5.3599,-4.0082,"2024-01-13","2024-02-11",0),
    ("2023","2024","Ivory Coast","Bouake",7.6936,-5.0319,"2024-01-13","2024-02-11",0),
    ("2023","2024","Ivory Coast","Yamoussoukro",6.8276,-5.2893,"2024-01-13","2024-02-11",0),
    ("2023","2024","Ivory Coast","San Pedro",4.7483,-6.6363,"2024-01-13","2024-02-11",0),
    ("2023","2024","Ivory Coast","Korhogo",9.4579,-5.6295,"2024-01-13","2024-02-11",0),
]

columnas = ["edition_year","tournament_year","host_country","city",
            "lat_city","lon_city","start_date","end_date","cohost"]

df = pd.DataFrame(data, columns=columnas)

# Convertir tipos
df["edition_year"]    = df["edition_year"].astype(int)
df["tournament_year"] = df["tournament_year"].astype(int)
df["start_date"]      = pd.to_datetime(df["start_date"])
df["end_date"]        = pd.to_datetime(df["end_date"])
df["cohost"]          = df["cohost"].astype(int)

print(f"Dataset cargado: {len(df)} filas, {len(df.columns)} columnas")
df.head()
# Out:
# Dataset cargado: 99 filas, 9 columnas
#    edition_year  tournament_year host_country         city  lat_city  \
# 0          1957             1957        Sudan     Khartoum   15.5007
# 1          1959             1959        Egypt        Cairo   30.0444
# 2          1959             1959        Egypt   Alexandria   31.2001
# 3          1962             1962     Ethiopia  Addis Ababa    9.0054
# 4          1963             1963        Ghana        Accra    5.6037
#
#    lon_city start_date   end_date  cohost
# 0   32.5599 1957-02-10 1957-02-16       0
# 1   31.2357 1959-05-22 1959-05-29       0
# 2   29.9187 1959-05-22 1959-05-29       0
# 3   38.7636 1962-01-10 1962-01-21       0
# 4   -0.1870 1963-11-03 1963-11-10       0

# %%
print("Ediciones cubiertas:", df["edition_year"].min(), "–", df["edition_year"].max())
print("Ciudades sede únicas:", df["city"].nunique())
print("Países organizadores:", df["host_country"].nunique())
print("\nColumnas actuales:", list(df.columns))
# Out:
# Ediciones cubiertas: 1957 – 2023
# Ciudades sede únicas: 63
# Países organizadores: 18
#
# Columnas actuales: ['edition_year', 'tournament_year', 'host_country', 'city', 'lat_city', 'lon_city', 'start_date', 'end_date', 'cohost']

# %%
df.to_csv("afcon_hostcities_base.csv", index=False, encoding="utf-8-sig")
print("Guardado")
# Out:
# Guardado

# %% [markdown]
# ##### Correcciones realizadas al archivo original `afcon_hostcities.do`
#
# | # | Variable | Edición | Ciudad | Valor Original | Valor Corregido | Fuente | Motivo |
# |---|---|---|---|---|---|---|---|
# | 1 | `start_date` | 1976 | Addis Ababa | 29feb1976 | 28feb1976 | Wikipedia - AFCON 1976 | 1976 no fue año bisiesto, la fecha no existe |

# %% [markdown]
# #### 1.1.2. Completar las variables faltantes

# %% [markdown]
# ##### Variables agregadas (no existían en el archivo original)
# | Variable | Fuente |
# |---|---|
# | `stadium_name` | Wikipedia, RSSSF (rsssf.org) |
# | `stadium_capacity` | Wikipedia, RSSSF (rsssf.org) |
# | `n_matches` | RSSSF (rsssf.org), Soccerway |
# | `lat_stadium` | Google Maps, OpenStreetMap |
# | `lon_stadium` | Google Maps, OpenStreetMap |

# %% [markdown]
# #### 1.1.3. Sede omitida del dataset de apoyo (agregando)

# %% [markdown]
# #### 1.1.4. Coordenadas geográficas precisas de cada estadio

# %% [markdown]
# ### 1.2. VARIABLES DEL DATASET FINAL

# %% [markdown]
# ### 1.3. MAPA DESCRIPTIVO

# %% [markdown]
# ### 1.4. ESTADÍSTICAS DESCRIPTIVAS
