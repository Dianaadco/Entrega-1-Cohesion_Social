# %%
# !git --version #para ver si tenemos github y si no debemos instalar https://git-scm.com/install/windows y luego probar de nuevo
# Out:
# git version 2.53.0.windows.2

# %%
# !pip install jupyterlab-git #para que aprezca en el interfaz

# %%
# !git config --global user.name "Dianaadco"
# !git config --global user.email "diana.adco97@email.com"

# %%
# !git init
# !git remote add origin https://github.com/Dianaadco/Entrega-1-Cohesion_Social.git
# Out:
# Initialized empty Git repository in C:/Users/LENOVO/Entrega1_CohesionSocial/.git/

# %%
# Para crearlo:
#GitHub → tu foto de perfil → Settings
#Scroll hasta abajo → Developer settings
#Personal access tokens → Tokens (classic)
#Generate new token → marca el permiso repo → genera y cópialo
#Una vez corra el siguiente codigo se abrira una pantalla y debere presioanrla y es asi cunaod se conectara.
# !git add .
# !git commit -m "primer commit"
# !git branch -M main
# !git push -u origin main
# Out:
# ...
# [main 3ec23fb] primer commit
#  1 file changed, 28 insertions(+), 1 deletion(-)
# branch 'main' set up to track 'origin/main'.
# To https://github.com/Dianaadco/Entrega-1-Cohesion_Social.git
#  * [new branch]      main -> main

# %%
# !git push -u origin main #volviendo a ejecutar
# Out:
# branch 'main' set up to track 'origin/main'.
# Everything up-to-date

# %% [markdown]
# Ahora cada vez que quiera modificar debo poner esto

# %%
# !git add .

# %%
# !git commit -m "descripción de lo que cambiaste"
# Out:
# [main db91dea] descripciÃ³n de lo que cambiaste
#  1 file changed, 84 insertions(+), 9 deletions(-)

# %%
# !git push
# Out:
# To https://github.com/Dianaadco/Entrega-1-Cohesion_Social.git
#    3ec23fb..db91dea  main -> main

# %%
print("Hola, mundo")
# Out:
# Hola, mundo
